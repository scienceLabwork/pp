# %% [markdown]
# ### 21BCM054 RUDRA
# ##### **Q1.** Design a python program which performs the linearregression operation on the given data to predict the house price. Also, visualize the data for different attributes.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model

# %%
data = pd.read_csv("Housing.csv")
df = pd.DataFrame(data)
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
plt.title("Heatmap of Housing Data")
sns.heatmap(df.corr(), annot=True)
# Out:
# /var/folders/7n/498x98q54bbb5n96tdgsbc8h0000gn/T/ipykernel_41091/2108677735.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <AxesSubplot:title={'center':'Heatmap of Housing Data'}>

# %%
plt.scatter(df["price"],df["area"])
plt.title("Price vs Area")
# Out:
# Text(0.5, 1.0, 'Price vs Area')

# %%
model = linear_model.LinearRegression()
model.fit(df[["area"]],df["price"])
# Out:
# LinearRegression()

# %%
model.predict([[3000]])
# Out:
# /Users/rudrashah/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3773233.16521478])

# %%
slope = model.coef_
slope
# Out:
# array([461.97489427])

# %%
intercept = model.intercept_
intercept
# Out:
# 2387308.482396427

# %%
df["area"]
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
df["price"]
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
plt.plot(df["area"],df["price"],"o")
plt.plot(df["area"],slope*df["area"]+intercept,"r")
plt.title("Price vs Area")
# Out:
# Text(0.5, 1.0, 'Price vs Area')

# %% [markdown]
# ##### **Q2.** Design a python program which implements thebisection and false positioning method.

# %%
# LAB
def f(x): 
    y = 2*(x**3) - 3*x - 1 
    return y 
a = -100
b = 100

def bisection(a,b):
    if f(a)*f(b)>0:
        print("Zero roots")
        return
    c =a
    while ((b-a)>=0.01):
        c = (a+b)/2
        if f(c)==0:
            break  
        if f(c)*f(a)<0:
            b = c  
        else:
            a=c 
    print("The root of the equation is:  %.3f"%c)

def falseposition(a, b):
    if f(a) * f(b) > 0:
        print("Take correct a and b\n")
        return
    c = a
    for i in range(1000000):
        c = (a*f(b) - b*f(a))/(f(b) - f(a))
        if f(c) == 0:
            break
        elif f(c) * f(a) < 0:
            b=c
        elif f(c)*f(b)<0:
            a=c     
    print("The root of the equation is:  %.3f"%c)

bisection(a,b)
falseposition(a,b)
# Out:
# The root of the equation is:  1.361
# The root of the equation is:  1.366
